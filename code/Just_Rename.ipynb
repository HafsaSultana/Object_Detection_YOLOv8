# %%
import os

def rename(source):
    """
    rename an existing image file and xml file which have the same name.
    """
    #print(source)
#A lot of times when dealing with iterators, we also get a need to keep a count of iterations. 
#Python eases the programmers’ task by providing a built-in function enumerate() for this task.
    #ct = st
    for count, filename in enumerate(os.listdir(source)):
        ext = filename.split(".")[-1]    # extracting extension
        f_n = filename.split(".")[0]     # extracting filename
        print(ext)
        if ext == "xml":
            dst = source + f_n + "_hb."+ ext
            dst_xml = source + f_n + "_hb." + "xml"
            #print(dst)
            src = source + filename
            src_xml = source + f_n + "." + "xml"
            #print(src)
            
            
            #dst = source + "ppp" + dst
            dst = source + dst
            
            
            dst_xml = source + dst_xml
            #print(dst)
            os.rename(src,dst)
            print("file \""+src+"\" renamed as \""+dst+"\"")
            try:
                os.rename(src_xml,dst_xml)
            except:
                print("not found")
            
        pass
    pass

# %%
rename("A/")
# Out:
# xml
# file "A/1.xml" renamed as "A/A/1_hb.xml"
# not found
# xml
# file "A/10.xml" renamed as "A/A/10_hb.xml"
# not found
# xml
# file "A/11.xml" renamed as "A/A/11_hb.xml"
# not found
# xml
# file "A/12.xml" renamed as "A/A/12_hb.xml"
# not found
# xml
# file "A/13.xml" renamed as "A/A/13_hb.xml"
# not found
# xml
# file "A/14.xml" renamed as "A/A/14_hb.xml"
# not found
# xml
# file "A/15.xml" renamed as "A/A/15_hb.xml"
# not found
# xml
# file "A/16.xml" renamed as "A/A/16_hb.xml"
# not found
# xml
# file "A/17.xml" renamed as "A/A/17_hb.xml"
# not found
# xml
# file "A/18.xml" renamed as "A/A/18_hb.xml"
# not found
# xml
# file "A/19.xml" renamed as "A/A/19_hb.xml"
# not found
# xml
# file "A/2.xml" renamed as "A/A/2_hb.xml"
# not found
# xml
# file "A/20.xml" renamed as "A/A/20_hb.xml"
# not found
# xml
# file "A/21.xml" renamed as "A/A/21_hb.xml"
# not found
# xml
# file "A/22.xml" renamed as "A/A/22_hb.xml"
# not found
# xml
# file "A/23.xml" renamed as "A/A/23_hb.xml"
# ...
