# %%
# !nvidia-smi
# Out:
# Thu Nov  2 08:41:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Pip install (recommended)

# !pip install ultralytics

# %%
#Creating train-val split

# %%
## importing required libraries
import os
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
## connecting to the google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian
# Out:
# data  dataset.yaml  output  training_results  yolov8_custom_training.ipynb

# %%
import os

# Replace this with your file or directory path
path_to_check = '/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/'

# Check if the path exists
if os.path.exists(path_to_check):
    print(f"The path '{path_to_check}' exists.")

    # Check if it's a directory
    if os.path.isdir(path_to_check):
        print(f"'{path_to_check}' is a directory.")
    else:
        print(f"'{path_to_check}' is a file.")
else:
    print(f"The path '{path_to_check}' does not exist.")
# Out:
# The path '/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/' exists.
# '/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/' is a directory.

# %% [markdown]
# Split the dataset into train and test and creates the train.txt and test.tx with
# the respective path of the images in each folder

# %% [markdown]
# Train:

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.1/78.2 GB disk)

# %%
#Command Line Interface:

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/dataset.yaml epochs=50 imgsz=800 batch=8 project=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/training_results name=Papaya
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# Validate Custom Model

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/training_results/Papaya/weights/best.pt data=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/dataset.yaml
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/validation/labels.cache... 83 images, 0 backgrounds, 0 corrupt: 100% 83/83 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 6/6 [00:09<00:00,  1.51s/it]
#                    all         83        938      0.904      0.921      0.957      0.726
# Speed: 9.2ms preprocess, 26.1ms inference, 0.0ms loss, 9.2ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
#Inferencing

# %%
# !yolo task=detect mode=predict save=True save_txt=True line_width=1 model=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/training_results/Papaya/weights/best.pt conf=0.5 source=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/test/images
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/83 /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/test/images/175_o.jpg: 608x800 7 Papayas, 63.8ms
# image 2/83 /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/test/images/176_o.jpg: 608x800 13 Papayas, 18.4ms
# image 3/83 /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/test/images/177_o.jpg: 608x800 14 Papayas, 18.4ms
# image 4/83 /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/test/images/178_o.jpg: 608x800 14 Papayas, 18.4ms
# image 5/83 /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/data/test/images/179_o.jpg: 608x800 8 Papayas, 18.4ms
# ...

# %%
# !cp -r /content/runs/detect/predict /content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/output

# %%
#Export the model -- In progress

# %%
# !yolo mode=export model=/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/training_results/Papaya/weights/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.0.203 🚀 Python-3.10.12 torch-2.1.0+cu118 CPU (Intel Xeon 2.00GHz)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/training_results/Papaya/weights/best.pt' with input shape (1, 3, 800, 800) BCHW and output shape(s) (1, 5, 13125) (21.5 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 61.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.8s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 9.3s, saved as '/content/drive/MyDrive/MScThesis/YOLOv8/Old_415_papaya_data/Org_Gaussian___Gaussian/training_results/Papaya/weights/best.onnx' (42.7 MB)
#
# ...
